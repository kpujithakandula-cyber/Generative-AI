# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model = "gemini-3.1-flash-lite"
)

# %%
result = llm.invoke("What is capital of France?")
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.

# %%
result
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The capital of France is Paris.', 'extras': {'signature': 'EnEKbwERTTIPJhTEpdOBzqYOu0UzfcQyUdu99BijOBtOhBEIHeWaCPnL0zeZ2RKijZrNZIhFgMUI93o/E45CB7mjSwQ8bPuC5K9uulEHjslpR0K1ERXyuENWNPFTEbAPp2eWv8IOLy/mXCjd1ZKsLuvKgw=='}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0aecf-f197-7cb0-b308-261fa1993f65-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7, 'output_tokens': 7, 'total_tokens': 14, 'input_token_details': {'cache_read': 0}})

# %%
result.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'type': 'text', 'text': 'The capital of France is Paris.', 'extras': {'signature': 'EnEKbwERTTIPJhTEpdOBzqYOu0UzfcQyUdu99BijOBtOhBEIHeWaCPnL0zeZ2RKijZrNZIhFgMUI93o/E45CB7mjSwQ8bPuC5K9uulEHjslpR0K1ERXyuENWNPFTEbAPp2eWv8IOLy/mXCjd1ZKsLuvKgw=='}}]

# %%
result1 = llm.invoke("What are the popular spots in capital of France?")
result1.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'type': 'text', 'text': 'Paris, the capital of France, is one of the most visited cities in the world. Its landmarks are iconic and spread across the city, mostly centered around the Seine River.\n\nHere are the most popular spots categorized by type:\n\n### 1. The Iconic Landmarks\n*   **Eiffel Tower:** The global symbol of France. You can view it from the Trocadéro gardens, picnic on the Champ de Mars, or go to the top for a panoramic view of the city.\n*   **Arc de Triomphe:** Located at the end of the Champs-Élysées, this monument honors those who fought for France. You can climb to the top for a great view of the radiating avenues.\n*   **Sacré-Cœur Basilica:** Perched on the highest point in the city in the bohemian neighborhood of Montmartre, this white-domed church offers one of the best free views of Paris.\n\n### 2. Museums & Art\n*   **The Louvre:** The world’s largest and most famous art museum. It houses the *Mona Lisa*, the *Venus de Milo*, and thousands of other treasures.\n*   **Musée d’Orsay:** Located in a stunning former railway station, this museum holds the world\'s largest collection of Impressionist and Post-Impressionist masterpieces (Monet, Van Gogh, Degas, Renoir).\n*   **Centre Pompidou:** Famous for its "inside-out" architecture, this is the center for modern and contemporary art in Paris.\n\n### 3. Historical & Religious Sites\n*   **Notre-Dame Cathedral:** A masterpiece of French Gothic architecture. While it is still undergoing restoration following the 2019 fire, its exterior remains a primary focal point on the Île de la Cité.\n*   **Sainte-Chapelle:** Located near Notre-Dame, this chapel is world-famous for its massive, breathtaking 13th-century stained-glass windows.\n*   **Panthéon:** A grand neoclassical building in the Latin Quarter where famous French figures like Victor Hugo, Marie Curie, and Voltaire are buried.\n\n### 4. Neighborhoods & Atmosphere\n*   **Le Marais:** One of the oldest and trendiest districts. It is filled with narrow medieval streets, mansions, boutiques, galleries, and excellent falafel shops.\n*   **Montmartre:** Known for its artistic history (Picasso and Dalí once lived here), cobblestone streets, and the Place du Tertre, where artists still set up their easels.\n*   **Latin Quarter:** Famous for its student atmosphere, the Sorbonne University, and the historic Shakespeare and Company bookstore.\n\n### 5. Parks & Gardens\n*   **Jardin du Luxembourg:** A beautiful, quintessentially Parisian park where locals go to read, play chess, or sail toy boats in the pond.\n*   **Tuileries Garden:** Located between the Louvre and the Place de la Concorde, it is perfect for a stroll after visiting the museum.\n\n### 6. Shopping & Strolls\n*   **Champs-Élysées:** Known as "the most beautiful avenue in the world," it is lined with luxury shops, cafes, and theaters.\n*   **Canal Saint-Martin:** A very local, "hip" area where people sit by the water with wine and picnic, far away from the heavy tourist crowds.\n\n### A Few Quick Tips:\n*   **Book ahead:** For the Eiffel Tower, the Louvre, and Sainte-Chapelle, it is highly recommended to book tickets online weeks in advance to avoid hours of waiting.\n*   **Walking is key:** Paris is a very walkable city; you will see much more by wandering through side streets than by taking the Metro between every major site.\n*   **The Seine:** Consider taking a *Bateau-Mouche* (river boat cruise) at night—seeing the monuments lit up from the water is a highlight for most travelers.', 'extras': {'signature': 'EnEKbwERTTIPH+Ou9z/k3p7TONIZ7LJ9aIMSKD1W2WzMnx4gCfVY/fLpLQE5TU5SQT7AajSlaBRBFoXPOJrGwjLH3I50ykiu3nP6AAGV53KSioe0jYKt3HeXvpi02Lz3TdDWLP6LgEJiUDxrd2nkbav1hw=='}}]

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model = "llama3.1"
)

# %%
result2 = llm.invoke("What is capital of India")
result2.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# The capital of India is New Delhi.
