# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model = "gemini-3.1-flash-lite"
)

# %%
result = llm.invoke("What is capital of France?")
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.

# %%
result
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The capital of France is **Paris**.', 'extras': {'signature': 'EnEKbwERTTIPCvzemsFE124ORFgx8s3ZdYSKo4+HjjwSEEldFVDVNCXrI1lRlXMebhKZUIyADYPt+8ywyuAgrxZ3GuSw92TTczxGPz6GDtErVJQ2L2819Av/0jcZtiwBE2WqeVm0yAKpa0zS7ViXyeu+GA=='}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0ae71-31d3-72d3-8e8e-3d0c5a88a39f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7, 'output_tokens': 8, 'total_tokens': 15, 'input_token_details': {'cache_read': 0}})

# %%
result.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'type': 'text', 'text': 'The capital of France is **Paris**.', 'extras': {'signature': 'EnEKbwERTTIPCvzemsFE124ORFgx8s3ZdYSKo4+HjjwSEEldFVDVNCXrI1lRlXMebhKZUIyADYPt+8ywyuAgrxZ3GuSw92TTczxGPz6GDtErVJQ2L2819Av/0jcZtiwBE2WqeVm0yAKpa0zS7ViXyeu+GA=='}}]

# %%
result1 = llm.invoke("What are the popular spots in capital of France?")
result1.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'type': 'text', 'text': 'Paris, the capital of France, is one of the most visited cities in the world. Its attractions are usually categorized by their historical significance, art, and iconic architecture.\n\nHere are the most popular spots you shouldn\'t miss:\n\n### 1. The Iconic Landmarks\n*   **Eiffel Tower:** The global symbol of France. You can view it from the Trocadéro gardens for the best photos, or go to the top for a panoramic view of the city.\n*   **Arc de Triomphe:** Standing at the western end of the Champs-Élysées, this massive arch honors those who fought for France. You can climb to the top for a great view of the 12 radiating avenues.\n*   **Sacré-Cœur Basilica:** Located at the highest point in the city in the neighborhood of Montmartre. It offers a stunning white-domed view and a breathtaking vista of Paris.\n\n### 2. World-Class Museums\n*   **The Louvre:** The world\'s largest art museum. It is home to thousands of works, including the *Mona Lisa* and the *Venus de Milo*. (Tip: Buy tickets well in advance).\n*   **Musée d’Orsay:** Housed in a stunning converted railway station, this museum holds the world’s largest collection of Impressionist and post-Impressionist masterpieces (Monet, Van Gogh, Renoir).\n*   **Centre Pompidou:** Famous for its "inside-out" architecture, this is the place to go for modern and contemporary art.\n\n### 3. Historical & Religious Sites\n*   **Notre-Dame Cathedral:** While it is still undergoing restoration following the 2019 fire, the exterior remains a masterpiece of French Gothic architecture and is a must-see while walking along the Seine.\n*   **Sainte-Chapelle:** Located near Notre-Dame, this chapel is famous for having some of the most beautiful and extensive 13th-century stained glass windows in the world.\n*   **Panthéon:** Located in the Latin Quarter, this mausoleum contains the remains of distinguished French citizens like Victor Hugo, Voltaire, and Marie Curie.\n\n### 4. Famous Neighborhoods & Streets\n*   **Montmartre:** Known for its artistic history and "village" feel. Wander the cobblestone streets, visit the Place du Tertre (where artists paint outdoors), and see the Moulin Rouge at the base of the hill.\n*   **Le Marais:** A trendy, historic district filled with medieval architecture, boutique shops, art galleries, and some of the best falafel and pastry shops in the city.\n*   **Champs-Élysées:** Often called "the world\'s most beautiful avenue," it is the place for high-end shopping, theaters, and cafes.\n\n### 5. Gardens and Public Spaces\n*   **Jardin du Luxembourg:** A beautiful park created in the 17th century, popular with both locals and tourists for reading, relaxing, and watching toy boats in the pond.\n*   **Tuileries Garden:** Located between the Louvre and the Place de la Concorde, this is the perfect place for a stroll after visiting the museum.\n\n### 6. Unique Experiences\n*   **The Seine River:** Taking a *Bateau-Mouche* (river boat cruise) is one of the most popular ways to see the city\'s monuments, especially at night when they are illuminated.\n*   **The Catacombs:** For those interested in the macabre, this network of underground tunnels holds the remains of over six million people.\n\n### Pro-Tips for Visitors:\n*   **Walking:** Paris is a very walkable city. Many of these sites are relatively close to each other.\n*   **Museum Pass:** If you plan on visiting many museums, consider the "Paris Museum Pass" to save money and skip some ticket lines.\n*   **Dining:** Don\'t just eat at the tourist spots near major landmarks. Wander into the side streets (especially in the 10th, 11th, or 18th arrondissements) for a more authentic and affordable dining experience.', 'extras': {'signature': 'EnEKbwERTTIPOqBFeImST8oJ/6CPvCVA3jvmidJpBy8VqRmd0NRBI/FUoGbt/YvVolyBjCiJWDHLuq9tVugk0cFAgDI6uWv66NWzCe1WSi9RVqELyLbAM+1CUYUOccFUuGUj1eiV5rSagY+adI6YniW5WA=='}}]
